# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %load_ext nb_black

# %%
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (14, 7)

# %% [markdown]
# -----------------

# %% [markdown]
# ## Load Weather

# %%
def read_weather(filename):
    df = pd.read_csv(
        filename, sep="\t", na_values=[-9999], names=["date", "tmax", "tmin", "precip"]
    )
    df.date = pd.to_datetime(df.date, format="%Y%m%d")
    df.tmax = df.tmax / 10
    df.tmin = df.tmin / 10
    df.precip = df.precip / 10

    return df


def plot_weather(weather_df):

    fig, (ax1, ax2) = plt.subplots(2, 1)
    sns.lineplot(data=weather_df, x="date", y="tmax", ax=ax1, label="tmax")
    sns.lineplot(data=weather_df, x="date", y="tmin", ax=ax1, label="tmin")
    sns.lineplot(data=weather_df, x="date", y="precip", ax=ax2)

    ax1.set_title("Temperature")
    ax1.set_ylabel("Degree Celsius")
    ax2.set_title("Precipitation")
    ax2.set_ylabel("")

# %%
w1 = read_weather("../DataSciTest/wx_data/USC00110072.txt")
w1[(w1.tmax.isna()) | (w1.tmin.isna()) | (w1.precip.isna())]
# Out:
#             date  tmax  tmin  precip
# 31    1985-02-01  -8.3   NaN     0.0
# 119   1985-04-30  24.4   NaN     5.8
# 2223  1991-05-05  17.2   7.2     NaN
# 2224  1991-05-06   9.4   5.0     NaN
# 2225  1991-05-07  20.0   1.7     NaN
# ...          ...   ...   ...     ...
# 10475 2013-12-07   NaN   NaN     0.0
# 10609 2014-04-20   NaN   NaN     0.0
# 10610 2014-04-21   NaN   NaN     0.0
# 10611 2014-04-22  17.8   NaN     0.5
# 10773 2014-10-01   NaN  10.0     0.0
#
# [444 rows x 4 columns]

# %%
plot_weather(w1)

# %%
def read_yield(filename):
    df = pd.read_csv(filename, sep="\t", names=["year", "corn_yield"])
    return df


def plot_yield(yield_df):
    yield_df.year = pd.to_datetime(yield_df.year, format="%Y")
    fig, ax = plt.subplots(1, 1)
    sns.lineplot(data=yield_df, x="year", y="corn_yield", ax=ax, marker="o")
    ax.set_title("US Corn Yield by Year")
    ax.set_ylabel("1000 Megatons")

# %%
y1 = read_yield("../DataSciTest/yld_data/US_corn_grain_yield.txt")
y1.head()
# Out:
#    year  corn_yield
# 0  1985      225447
# 1  1986      208944
# 2  1987      181143
# 3  1988      125194
# 4  1989      191320

# %%
plot_yield(y1)
